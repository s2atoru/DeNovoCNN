# %%
import tensorflow as tf

model = tf.keras.models.load_model("models/del")
model.save("models/del_new")

# %%
# save model as legacy h5 format
model.save("models/del.h5")

# %%
model = tf.keras.models.load_model("models/ins")
model.save("models/ins_new")

# %%
# save model as legacy h5 format
model.save("models/ins.h5")

# %%
model = tf.keras.models.load_model("models/snp")
model.save("models/snp_new")

# %%
# save model as legacy h5 format
model.save("models/snp.h5")

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices("GPU")
if gpus:
    print("CUDAが利用可能です。使用中のGPU:")
    for gpu in gpus:
        print(f"  - {gpu.name}")
else:
    print("CUDAは利用できません。")
